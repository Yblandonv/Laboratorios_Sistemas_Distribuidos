# %% [markdown]
# # Apache Spark en Google Colab
# Ejercicios de WordCount, DataFrame API y MLlib (clasificación)

# %%
#configuración en google colab de spark y pyspark
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !apt-get install openjdk-17-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-4.0.1/spark-4.0.1-bin-hadoop3.tgz
# !tar xf spark-4.0.1-bin-hadoop3.tgz
# !pip install -q findspark
# !pip install -q pyspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-4.0.1-bin-hadoop3"
import findspark
findspark.init()

# %% [markdown]
# ## Ejemplo 1: WordCount con RDD

# %%
from pyspark import SparkContext
sc = SparkContext.getOrCreate()

text = sc.textFile("/content/gdrive/MyDrive/datasets/gutenberg-small/*.txt")
# Simular archivo de texto
# text = sc.parallelize(["Hola Spark Hola Big Data", "Spark es rápido y poderoso"])
counts = text.flatMap(lambda x: x.split(" ")) \
             .map(lambda x: (x, 1)) \
             .reduceByKey(lambda a, b: a + b)
counts.collect()
# Out:
# [('', 27298),
#  ('Published', 3),
#  ('themselves', 192),
#  ('were', 1450),
#  ('sheet', 4),
#  ('despatched', 4),
#  ('most', 551),
#  ('turbulent', 2),
#  ('A.', 1456),
#  ('ORIGINALS', 1),
#  ('IN', 84),
#  ('BROTHER]', 2),
#  ('more', 1211),
#  ('forget', 46),
#  ('prove', 113),
#  ('Give', 14),
#  ('Johnston:--', 1),
#  ('request', 53),
#  ('comply', 10),
#  ('times', 117),
#  ('know.', 24),
#  ('doubt', 134),
#  ("day's", 8),
#  ('does', 445),
#  ('what', 1162),
#  ('nail,"', 3),
#  ('Let', 249),
#  ('fair', 127),
#  ('own', 664),
#  ('dollar.', 5),
#  ('yourself', 67),
#  ('County.', 16),
#  ('ever.', 20),
#  ("months'", 7),
#  ('it?', 167),
#  ('mine.', 24),
#  ('power', 430),
#  ('give,', 10),
#  ('cause,', 44),
#  ('APPROVAL', 2),
#  ('First', 28),
#  ('States,', 567),
#  ('consider', 165),
#  ('seems', 147),
#  ('accession', 8),
#  ('Republican', 186),
#  ('cause', 184),
#  ('believe', 421),
#  ('so,', 180),
#  ('Those', 38),
#  ('acceptance,', 7),
#  ('rights', 124),
#  ('control', 125),
#  ('invasion', 23),
#  ('under', 741),
#  ('pretext,', 4),
#  ('sentiments;', 6),
#  ('susceptible,', 4),
#  ('fugitives', 11),
#  ('fugitive', 41),
#  ('slaves;', 16),
#  ('then,', 248),
#  ('cases', 141),
#  ('unsubstantial', 4),
#  ('case,', 132),
#  ('rules.', 5),
#  ('stand', 149),
#  ('have,', 69),
#  ('executive', 46),
#  ('branch', 55),
#  ('formidably', 4),
#  ('universal', 38),
#  ('ever', 512),
#  ('provisions', 55),
#  ('nature', 85),
#  ('merely,', 13),
#  ('require', 88),
#  ('matured,', 7),
#  ('declared', 150),
#  ('FORM', 4),
#  ('faithfully', 33),
#  ('Constitutionally', 1),
#  ('using', 34),
#  ('Where', 21),
#  ('obnoxious', 10),
#  ('strict', 23),
#  ('favorable', 56),
#  ('show', 249),
#  ('fraternal', 12),
#  ('speak?', 5),
#  ('hazard', 18),
#  ('ones', 37),
#  ('this.', 124),
#  ('constitutional', 209),
#  ('acquiesce,', 8),
#  ('alternative;', 4),
#  ('disunion', 29),
#  ('produce', 54),
#  ('checks', 4),
#  ('opinions', 57),
#  ('decisions', 37),
#  ('evil', 63),
#  ('cases,', 33),
#  ('actions,', 7),
#  ('revived,', 5),
#  ('remain', 107),
#  ('intercourse,', 12),
#  ('Can', 94),
#  ('Whenever', 25),
#  ('modes', 8),
#  ('administer', 15),
#  ('Nations,', 3),
#  ('truth', 127),
#  ('wisely', 16),
#  ('intervals.', 4),
#  ('dissatisfied', 24),
#  ('precipitate', 5),
#  ('action.', 29),
#  ('favored', 11),
#  ('assail', 12),
#  ('battlefield', 8),
#  ('be,', 132),
#  ('fathers', 149),
#  ('.', 25),
#  ('ground.', 23),
#  ('birth', 15),
#  ('AT', 83),
#  ('Copyright,', 1),
#  ('FIRST', 13),
#  ('June', 174),
#  ('Hall,', 7),
#  ('Proclamation,', 14),
#  ('Mr.', 676),
#  ('all.', 131),
#  ('himself', 262),
#  ('claims', 75),
#  ('recognition', 26),
#  ('effort,', 9),
#  ('degree', 67),
#  ('individual.', 3),
#  ('small', 106),
#  ('writer', 18),
#  ('Among,', 1),
#  ('writings,', 5),
#  ('closely', 15),
#  ('conversations', 4),
#  ('charm', 4),
#  ('sway', 4),
#  ('member', 85),
#  ('portending', 1),
#  ('Douglass,', 1),
#  ('white', 259),
#  ('anyone', 3),
#  ('State.', 149),
#  ('statesmen', 17),
#  ('Like', 13),
#  ('remotely,', 1),
#  ('Legislature,', 28),
#  ('speaker,', 4),
#  ('thinking', 45),
#  ('words', 92),
#  ('constantly', 103),
#  ('adding', 20),
#  ('ornament', 3),
#  ('trace.', 1),
#  ('words."', 1),
#  ('heroes', 2),
#  ('style:', 1),
#  ('Lincoln-Douglas', 5),
#  ('1856.', 19),
#  ('Birthday,', 1),
#  ('speaker.', 2),
#  ('reformation.', 2),
#  ('companions', 2),
#  ('muse', 1),
#  ('applause,', 2),
#  ('noted', 9),
#  ('aptness', 1),
#  ('ruled', 5),
#  ('matter.', 42),
#  ('1852', 6),
#  ('model', 7),
#  ('poise', 1),
#  ('quotations.', 1),
#  ('example,', 14),
#  ('quiet', 29),
#  ('"You', 16),
#  ('hearers', 4),
#  ('notes', 28),
#  ('occasion,', 49),
#  ('believing', 20),
#  ('character.', 22),
#  ('powerful', 30),
#  ('speakers', 8),
#  ('include', 35),
#  ('inclined', 30),
#  ('reception.', 8),
#  ('lines', 48),
#  ('consciousness', 14),
#  ('commentaries', 1),
#  ('history,', 41),
#  ('prose.', 1),
#  ('Writers', 1),
#  ('refer', 32),
#  ('Messages', 2),
#  ('feasts.', 1),
#  ('Midway', 1),
#  ('Debates,', 2),
#  ('colleges,', 1),
#  ('plain,', 13),
#  ('condensation', 1),
#  ('HISTORY.', 1),
#  ('born.', 4),
#  ('1819.', 1),
#  ('1822.', 1),
#  ('1838.', 2),
#  ('Senate.', 29),
#  ('1860.', 23),
#  ('Kansas', 114),
#  ('Mar.', 1),
#  ('benefited', 5),
#  ('roads,', 9),
#  ('navigable', 5),
#  ('them--as', 2),
#  ('paying', 33),
#  ('possess,', 6),
#  ('cost,', 13),
#  ('1831,', 2),
#  ('inattentive', 1),
#  ('three-fourths', 7),
#  ('turf,', 1),
#  ('zigzag', 1),
#  ('necks', 5),
#  ('county;', 3),
#  ('approbation', 15),
#  ('support.', 12),
#  ('annually', 5),
#  ('erroneous,', 10),
#  ('Christian', 38),
#  ('freemen', 8),
#  ('savage', 5),
#  ('non-slave-holding', 1),
#  ('certainly', 140),
#  ('State;', 25),
#  ('fate.', 7),
#  ('hanging,', 2),
#  ('gamblers', 6),
#  ('citizens,', 32),
#  ('there.', 58),
#  ('short,', 17),
#  ('street,', 3),
#  ('consequences', 28),
#  ('pernicious', 4),
#  ('murderers,', 8),
#  ('guilty', 37),
#  ('deadliest', 2),
#  ('forebodes', 2),
#  ('thousands', 18),
#  ('suffer', 30),
#  ('affections', 4),
#  ('tolerate', 18),
#  ('reverence', 9),
#  ('taught', 25),
#  ('seminaries,', 3),
#  ('poor,', 12),
#  ('colors', 7),
#  ('grievances', 3),
#  ('made.', 31),
#  ('_no', 2),
#  ('destiny', 8),
#  ('aspired', 2),
#  ('revered', 8),
#  ('toasted', 2),
#  ('seat', 22),
#  ('Towering', 3),
#  ('regions', 25),
#  ('_denies_', 1),
#  ('illustrious.', 3),
#  ('_passions_', 1),
#  ('adult', 3),
#  ('invading', 8),
#  ('_has', 1),
#  ('done_--the', 1),
#  ('materials', 14),
#  ('"_the', 1),
#  ('whither', 8),
#  ('avowed', 35),
#  ('agitation', 72),
#  ('machinery', 14),
#  ('constitutions,', 6),
#  ('_one_', 1),
#  ('voluntarily', 25),
#  ('prohibition,', 9),
#  ('argued', 19),
#  ('election.', 31),
#  ('reputed', 3),
#  ('Kansas;', 8),
#  ('_up_.', 1),
#  ('scaffolding--like', 1),
#  ('involves', 5),
#  ('descendant', 3),
#  ('enhance', 5),
#  ('permanency', 3),
#  ('partially,', 5),
#  ('latter,', 10),
#  ('niche', 11),
#  ('dreaded', 12),
#  ('in--in', 1),
#  ('lumped', 3),
#  ('Mace', 4),
#  ('other?', 13),
#  ('dreaming', 3),
#  ('dynasty;', 1),
#  ('regularly', 15),
#  ('buy', 50),
#  ('producers', 3),
#  ('aught', 10),
#  ('interposed', 3),
#  ('Gentlemen;', 1),
#  ('reply', 60),
#  ('exceeding', 18),
#  ('responsible', 68),
#  ("Judge's", 41),
#  ('interrogatory', 14),
#  ('unwilling', 32),
#  ('Capital', 9),
#  ('Douglas.', 44),
#  ('conceive', 28),
#  ('comments', 17),
#  ('Abolitionism', 5),
#  ('convention;', 3),
#  ('discovery', 13),
#  ('roundly', 6),
#  ('extraordinary_', 1),
#  ('conduct', 56),
#  ('adversaries,', 8),
#  ('Well,', 46),
#  ('occupying,', 2),
#  ('introduced', 54),
#  ('intend', 48),
#  ("Chase's", 16),
#  ('party--to', 2),
#  ('dignity', 7),
#  ('was?', 3),
#  ('go.', 14),
#  ('chose', 9),
#  ('answer?', 3),
#  ('[Cries', 11),
#  ('slavery--a', 1),
#  ('bluffing', 2),
#  ('amended,', 2),
#  ('wanted.', 5),
#  ('recall', 10),
#  ('"fatal', 11),
#  ('authority."', 2),
#  ('discovers', 4),
#  ('instrument.', 10),
#  ('COOPER', 3),
#  ('observations', 2),
#  ('subsequently', 14),
#  ('authority,', 62),
#  ('prohibiting', 19),
#  ('Few,', 5),
#  ('prohibition--thus', 1),
#  ('passage.', 2),
#  ('Carroll,', 2),
#  ('constrained', 17),
#  ('Baldwin.', 3),
#  ('was:', 4),
#  ('settler;', 2),
#  ('violated', 11),
#  ('Pinckney,', 2),
#  ('counting', 6),
#  ('live,"', 11),
#  ('grounds', 21),
#  ('Territories;', 9),
#  ('live"', 10),
#  ('law;"', 1),
#  ('inconsistent?', 2),
#  ('experience--to', 2),
#  ('clear,', 9),
#  ('leisure', 6),
#  ('opinion--thus', 2),
#  ('listen--as', 2),
#  ('contentions', 3),
#  ('Republicanism"', 3),
#  ('proof', 37),
#  ('such.', 14),
#  ('warning', 21),
#  ('Bearing', 6),
#  ('slaves.', 42),
#  ('persist', 5),
#  ('results.', 8),
#  ('continual', 5),
#  ('revolt.', 3),
#  ('institution--the', 3),
#  ('revolt', 7),
#  ('assassination', 3),
#  ("Helper's", 3),
#  ('Book,', 4),
#  ('scatter', 5),
#  ('army', 227),
#  ('fire;', 5),
#  ('enlarged', 15),
#  ('Bear', 3),
#  ('obvious', 20),
#  ('Constitution--decided', 3),
#  ('murderer!"', 3),
#  ('Confederacy', 14),
#  ('insurrections;', 3),
#  ('_wrong_,', 1),
#  ('_right_.', 1),
#  ('nowhere', 6),
#  ('socially', 9),
#  ('social,', 13),
#  ('Disunionists,', 3),
#  ('dungeons', 4),
#  ('leave,', 10),
#  ('rested', 14),
#  ('emotion', 5),
#  ('distracted', 10),
#  ('raising', 28),
#  ('SERENADE,', 9),
#  ('great.', 5),
#  ('modest', 7),
#  ('himself.', 34),
#  ('doubt.', 8),
#  ('Slavery.', 2),
#  ('errors', 11),
#  ('abideth', 3),
#  ('combination', 19),
#  ('repeat:', 4),
#  ('line,', 42),
#  ('Kentucky,', 58),
#  ('borders', 10),
#  ('presented;', 1),
#  ('find,', 11),
#  ('adoption?', 3),
#  ('past', 51),
#  ('peaceful,', 9),
#  ('applaud,', 2),
#  ('following,', 22),
#  ('free;', 26),
#  ('Bonne,', 2),
#  ('Virginia', 86),
#  ('Ann,', 2),
#  ('act,', 46),
#  ('supplications', 5),
#  ('customary', 14),
#  ('tender', 36),
#  ('sieges', 2),
#  ('estate,', 3),
#  ('paths', 6),
#  ('range,', 5),
#  ('rebel', 73),
#  ('groundless.', 10),
#  ('rejected', 17),
#  ('consistent', 24),
#  ('vanquished', 5),
#  ('politics,"', 2),
#  ('stake', 11),
#  ('England,', 11),
#  ('Peace', 6),
#  ('hinder', 14),
#  ('sober.', 3),
#  ('diligently', 8),
#  ('doubting', 11),
#  ('BIXBY', 1),
#  ('seeking', 25),
#  ('insurgents', 32),
#  ('attained.', 7),
#  ('faces;', 2),
#  ("bondman's", 2),
#  ('bind', 11),
#  ('Grant,', 33),
#  ('recent', 55),
#  ('differ', 21),
#  ('freed', 23),
#  ('plan,', 17),
#  ('sustaining', 20),
#  ('immaterial,', 2),
#  ('immaterial', 4),
#  ('12,000,', 1),
#  ('schools', 5),
#  ('cup', 3),
#  ('paralyzing', 3),
#  ('questionable,', 2),
#  ('questioned,', 5),
#  ('announcement', 12),
#  ('Macon', 6),
#  ('grandfather,', 3),
#  ('Spencer', 3),
#  ('happened', 22),
#  ('captain', 12),
#  ('Journal.', 4),
#  ('rhetorically', 1),
#  ('repeated', 32),
#  ('"_A', 2),
#  ('xii.', 1),
#  ('null', 4),
#  ('minutes.', 4),
#  ('1857', 6),
#  ('Pierce,', 4),
#  ('Samuel', 16),
#  ('21', 2),
#  ('correct.', 6),
#  ('law_.', 1),
#  ('statute', 16),
#  ('emphatically,', 2),
#  ('Convention_.', 1),
#  ('party."', 2),
#  ('"_Popular', 1),
#  ('Yorkers,', 1),
#  ("Greeley's", 1),
#  ('already--that', 1),
#  ('added', 46),
#  ('Parker,', 3),
#  ('print.', 3),
#  ('MERWIN', 1),
#  ('WORDS', 2),
#  ('MORTAL', 1),
#  ('rhetoric.', 1),
#  ('Burke', 1),
#  ('possessed?', 1),
#  ('reflection,', 11),
#  ('moments', 6),
#  ('course.', 7),
#  ('observant', 1),
#  ('convey', 6),
#  ('belonged,', 2),
#  ('quietly,', 2),
#  ('vehemence', 1),
#  ('wrought', 15),
#  ('meditated', 2),
#  ('innate', 2),
#  ('cogent', 1),
#  ('impressive', 5),
#  ('deals', 7),
#  ('fundamentals--the', 1),
#  ('community.', 9),
#  ('conclusions', 5),
#  ('position.', 29),
#  ('debated', 3),
#  ('occasionally', 7),
#  ('thoughtful,', 1),
#  ('failure.', 3),
#  ('mainspring', 1),
#  ('BRYCE', 1),
#  ('Monument,', 1),
#  ('1866;', 2),
#  ('Proclamation--Second', 1),
#  ('J.R.', 1),
#  ('Talk', 1),
#  ('Jones,', 3),
#  ('WORKS,', 1),
#  ('Compilation', 1),
#  ('Edition),', 1),
#  ('Personal', 1),
#  ('1872;', 1),
#  ('1902;', 1),
#  ('Philosophical', 2),
#  ('Men,', 4),
#  ('J.C.', 1),
#  ('D.', 263),
#  ('Law', 2),
#  ('Reply', 20),
#  ('Aug.', 19),
#  ('Speech,"', 3),
#  ('17,', 60),
#  ('Charleston,', 20),
#  ('28,', 58),
#  ('Moulton,', 1),
#  ('Day', 3),
#  ('courtesy', 4),
#  ('allowing', 25),
#  ('"Lincoln\'s', 2),
#  ('N.W.', 1),
#  ('Edwards', 11),
#  ('confidence,', 15),
#  ('traitor', 4),
#  ('selected.', 4),
#  ('rear', 8),
#  ('these,--the', 1),
#  ('related;', 1),
#  ('Browning.', 3),
#  ('journey,', 4),
#  ('remembered,', 5),
#  ('maid,"', 2),
#  ('weather-beaten', 2),
#  ('woman', 26),
#  ('rashness', 2),
#  ('fall),', 2),
#  ('consummation', 11),
#  ('mortified,', 3),
#  ('intentions,', 4),
#  ('girls,', 3),
#  ('Lamborn', 5),
#  ('err', 3),
#  ('cork', 2),
#  ('Julius', 3),
#  ('laudable', 8),
#  ('hundreds,', 2),
#  ('abstract', 23),
#  ('"we', 9),
#  ('warm-blooded', 2),
#  ('Egyptian', 5),
#  ('influenced,', 2),
#  ('friend.', 9),
#  ('convincing', 6),
#  ('rye', 2),
#  ('fiendishly', 3),
#  ('remote', 2),
#  ('loans', 24),
#  ('taxation.', 7),
#  ('taxation,', 2),
#  ('rest--or', 2),
#  ('locusts,', 2),
#  ('luxuries,', 2),
#  ('chains,', 3),
#  ('haunted', 3),
#  ('penniless', 6),
#  ('pride,', 6),
#  ('March.', 3),
#  ('"short', 2),
#  ('mischief', 7),
#  ('hunted', 6),
#  ('Ready', 2),
#  ('Take', 16),
#  ('Logan,', 11),
#  ('Lewis', 3),
#  ('wheat', 3),
#  ('spend', 12),
#  ('like,--make', 1),
#  ('failure', 18),
#  ('nominal', 10),
#  ('claimed.', 2),
#  ('mortal', 18),
#  ('fee-note--at', 1),
#  ('occupation,', 6),
#  ('prove,', 4),
#  ('Proviso.', 6),
#  ('adjourning', 2),
#  ('"Provided,', 2),
#  ('next?', 6),
#  ('politically', 12),
#  ('founded,', 4),
#  ('hog', 4),
#  ('humanity', 9),
#  ('percentage', 7),
#  ('price.', 5),
#  ('grows', 7),
#  ('inducing', 5),
#  ('something?', 2),
#  ('kickings,', 2),
#  ('poet', 3),
#  ('in,--I', 2),
#  ('councils', 6),
#  ('Canada.', 3),
#  ('nevertheless', 20),
#  ('assumes', 25),
#  ('eschewed', 2),
#  ('crown', 1),
#  ('bite', 3),
#  ('shackled', 2),
#  ('Must', 6),
#  ('violence.', 16),
#  ('1856_', 1),
#  ('Danville', 3),
#  ('delegates', 25),
#  ('_blood', 1),
#  ('chill', 3),
#  ('_Free-Soil_', 1),
#  ('_Kansas', 2),
#  ('pinch--is', 2),
#  ('"Abolitionist,"', 2),
#  ('despise.', 2),
#  ('name--the', 2),
#  ('deceived.', 7),
#  ('men_"?', 1),
#  ('hapless', 2),
#  ('Hill', 4),
#  ('fritter', 2),
#  ('generalities;"', 1),
#  ('trifling', 5),
#  ('neutral,', 2),
#  ('prostituted', 4),
#  ('fearless', 2),
#  ('stronghold', 3),
#  ('alike.', 4),
#  ('resolved', 22),
#  ('committee,', 14),
#  ('radical', 11),
#  ('Northwest,', 5),
#  ('failed;', 3),
#  ('State--in', 2),
#  ('civilization', 5),
#  ('trail', 2),
#  ('grizzled', 2),
#  ('[Laughter.]', 4),
#  ('whipped', 4),
#  ("won't", 20),
#  ('brave"', 2),
#  ('fair,', 3),
#  ('difference--between', 2),
#  ('_our_', 1),
#  ('it),', 4),
#  ('virtue."', 2),
#  ('knock', 2),
#  ('shook', 4),
#  ('"_Dug_!"]', 1),
#  ('_free_,', 1),
#  ('to-day?', 5),
#  ('craft,', 2),
#  ('Stringfellow,', 2),
#  ('Joneses', 2),
#  ('FOUL', 2),
#  ('concretely,', 2),
#  ('word."', 2),
#  ('bludgeon,', 2),
#  ('embers', 2),
#  ('ballots', 9),
#  ('Williams,', 4),
#  ('(instead', 3),
#  ('race?', 2),
#  ('ordinance', 18),
#  ('temporarily,', 5),
#  ('persevered', 2),
#  ('neighbour', 4),
#  ('($1,000,000,000);', 1),
#  ('darker', 4),
#  ('weeded', 2),
#  ('eleven', 12),
#  ('entitle', 6),
#  ('Union,"', 2),
#  ('applauded,', 2),
#  ('prejudices;', 2),
#  ('notes.', 1),
#  ('remarkably', 3),
#  ('differently', 9),
#  ('fashionable', 3),
#  ('philosophy', 10),
#  ('key;', 1),
#  ('mangled', 1),
#  ('races!', 2),
#  ('subjects;', 3),
#  ('preparing', 30),
#  ('doubts,', 4),
#  ('argued,', 2),
#  ('indorsing', 7),
#  ('Buchanan),--and', 1),
#  ('slave-trade?--how', 1),
#  ('decided--no', 2),
#  ('Yes,', 13),
#  ('Trumbull?', 3),
#  ('extinction,', 17),
#  ('nationalizing', 6),
#  ('consolidated', 7),
#  ('sugar-cane', 4),
#  ('bank', 33),
#  ('warfare', 10),
#  ('built', 15),
#  ('close,', 7),
#  ('mixture', 5),
#  ('indorsed,', 3),
#  ('kingcraft', 2),
#  ('class;', 3),
#  ('argument;', 3),
#  ('stop?', 2),
#  ('Scripture.', 3),
#  ('heaven;', 3),
#  ('"As', 7),
#  ('attained', 7),
#  ('traces', 3),
#  ('detain', 15),
#  ('disadvantage', 7),
#  ('politicians', 14),
#  ('warrantable.', 2),
#  ('misrepresenting', 2),
#  ('inside', 9),
#  ('respects;', 4),
#  ('misrepresentation', 6),
#  ('this;', 14),
#  ('fantastic', 6),
#  ('veracity,', 7),
#  ('nationalization', 6),
#  ('Prairie,', 2),
#  ('grow?', 2),
#  ('amiable,', 10),
#  ('slavery--I', 1),
#  ('statutes', 5),
#  ('Lord."', 6),
#  ('teeth', 15),
#  ('displeased', 4),
#  ('conditionally', 6),
#  ('it!"', 1),
#  ('(I', 14),
#  ('leg,', 2),
#  ('frankly,', 4),
#  ('complimented', 6),
#  ('him),', 3),
#  ('entertain,', 2),
#  ('prohibits', 4),
#  ('Because', 13),
#  ('citizenship....', 1),
#  ('affirmation.', 2),
#  ('matter....', 1),
#  ('Harris,', 4),
#  ('narrowed', 5),
#  ('exonerate', 3),
#  ('show.', 7),
#  ('Yates', 4),
#  ("Harris's", 3),
#  ('charity;', 1),
#  ('enlarging', 15),
#  ('resisting', 16),
#  ('misplaced', 3),
#  ('man,--I', 1),
#  ('Democrat,', 11),
#  ('truth?', 5),
#  ('Tract', 4),
#  ('irresistible', 5),
#  ('about,--a', 1),
#  ('please....', 1),
#  ('dressing', 1),
#  ('positively', 13),
#  ('sapper.', 2),
#  ('misunderstood', 9),
#  ('incipient', 5),
#  ('antagonism', 4),
#  ('ignores', 3),
#  ('Douglas;', 6),
#  ('accordingly.', 11),
#  ('movable', 5),
#  ('society.', 7),
#  ('desire,', 10),
#  ('sovereignty";', 4),
#  ('Plot', 1),
#  ('1861_', 11),
#  ('accepting', 18),
#  ('Imploring', 2),
#  ('Miss,', 1),
#  ('15th', 22),
#  ('whiskers,', 5),
#  ('coercion', 8),
#  ('airy.', 2),
#  ('bond,', 1),
#  ('primary', 11),
#  ('inhabitants,', 6),
#  ('anything:', 1),
#  ('Country;', 3),
#  ('repeatedly', 9),
#  ('productions.', 1),
#  ('ever--it', 1),
#  ('sophistry', 3),
#  ('assailants', 4),
#  ('republics,', 3),
#  ('indifferently', 2),
#  ('"United', 4),
#  ('Government;', 5),
#  ('aggregate,', 4),
#  ('remain.', 6),
#  ('pressing', 22),
#  ('sailor', 2),
#  ('invoked', 4),
#  ('aiding', 10),
#  ('structure', 7),
#  ('available', 24),
#  ('mingle', 6),
#  ('yours.', 12),
#  ('mine?', 8),
#  ('_Fourth._', 1),
#  ('Fitz', 2),
#  ('disobey', 3),
#  ('once?', 4),
#  ('follows:--_Resolved,', 1),
#  ('abolishment', 11),
#  ('private,', 7),
#  ('ranging,', 2),
#  ('cheaply', 3),
#  ('Break', 2),
#  ('inclination.', 4),
#  ('W----', 1),
#  ('nobody.', 3),
#  ('"New', 4),
#  ('memorial', 13),
#  ('revelation.', 2),
#  ('difficult,', 2),
#  ('River', 40),
#  ('advisement.', 1),
#  ('assembling,', 1),
#  ('harvests', 6),
#  ('difficulties,', 12),
#  ('Nevertheless,', 9),
#  ('self-defence;', 2),
#  ('Done', 32),
#  ('faith,', 14),
#  ('officer', 55),
#  ('distress', 9),
#  ('receipt', 31),
#  ('_Lear_,', 1),
#  ('hoped', 41),
#  ('developments', 7),
#  ('women', 17),
#  ('compliments', 3),
#  ('limb.', 3),
#  ('anyhow', 1),
#  ('liberator,', 2),
#  ('jewel.', 2),
#  ('in:', 1),
#  ('widow', 13),
#  ('compliment.', 3),
#  ('incidentally', 1),
#  ('Or,', 1),
#  ('co-operation,', 2),
#  ('wants,--and', 1),
#  ('RICHMOND', 1),
#  ('Described', 1),
#  ('cloud', 2),
#  ('throng.', 1),
#  ('husbands,', 1),
#  ('crying,', 1),
#  ('adjoining', 11),
#  ('watch,', 3),
#  ('"Now,', 6),
#  ('delay."', 1),
#  ('JOY', 1),
#  ('impair', 4),
#  ('Amnesty', 1),
#  ("S----'s", 1),
#  ('rope,', 1),
#  ('REBUFF', 1),
#  ('steady,', 1),
#  ('Southwest--the', 1),
#  ('shop', 2),
#  ('difference."', 1),
#  ('Sallie', 1),
#  ("isn't", 1),
#  ('leisurely', 1),
#  ('card?"', 1),
#  ('"examine', 1),
#  ('averting', 2),
#  ('munitions,', 2),
#  ('detention', 6),
#  ('predecessor', 5),
#  ('investing', 4),
#  ('1861,', 63),
#  ('receipts', 40),
#  ('militia', 44),
#  ('commenced.', 7),
#  ('Oregon', 5),
#  ('proposed--the', 2),
#  ('final.', 4),
#  ('delicacy,', 3),
#  ('Department:', 2),
#  ('transportation', 17),
#  ('$4,557,462.71.', 2),
#  ('4', 15),
#  ('viz,', 1),
#  ('obstructed', 5),
#  ('Northwest.', 4),
#  ('payment', 30),
#  ('inhuman', 5),
#  ('convicted', 12),
#  ('upheld', 5),
#  ('partly', 18),
#  ('scruples', 3),
#  ('unprofitable.', 2),
#  ('painfully', 9),
#  ("Dixon's", 3),
#  ('closes', 3),
#  ('cross-purposes', 2),
#  ('Labor', 8),
#  ('to-day;', 3),
#  ('jealous', 5),
#  ('neighbors,', 4),
#  ('Granada', 6),
#  ('auspicious.', 2),
#  ('economically', 2),
#  ('view.', 11),
#  ('weight,', 2),
#  ('reconcile', 4),
#  ('revenue.', 4),
#  ('destroyed.', 3),
#  ('noticed', 9),
#  ('seeds,', 2),
#  ('1900,', 2),
#  ('annum', 3),
#  ('reintroducing', 2),
#  ('continue.', 2),
#  ('hail', 3),
#  ('obliges', 5),
#  ('compensation,', 4),
#  ('seem,', 5),
#  ('paid,', 15),
#  ('103,208,415.', 2),
#  ('resource.', 2),
#  ('many?', 2),
#  ('mountains,', 6),
#  ('80.', 1),
#  ('34.60', 1),
#  ...]

# %% [markdown]
# ## Ejemplo 2: Análisis con DataFrame API

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# Simular DataFrame de ventas
data = [("martillo", 12000), ("taladro", 45000), ("martillo", 15000)]
columns = ["producto", "valor"]
df = spark.createDataFrame(data, columns)
df.groupBy("producto").sum("valor").show()
# Out:
# +--------+----------+
# |producto|sum(valor)|
# +--------+----------+
# |martillo|     27000|
# | taladro|     45000|
# +--------+----------+

# %% [markdown]
# ## Ejemplo 3: Clasificación con MLlib

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import LogisticRegression

df = spark.read.csv("/content/gdrive/MyDrive/datasets/clientes.csv", header=True, inferSchema=True)

assembler = VectorAssembler(inputCols=["edad", "ingresos"], outputCol="features")
data = assembler.transform(df).select("features", df["comprador"].alias("label"))
train, test = data.randomSplit([0.8, 0.2], seed=42)
lr = LogisticRegression()
model = lr.fit(train)
model.transform(test).select("features", "label", "prediction").show()
# Out:
# +-------------+-----+----------+
# |     features|label|prediction|
# +-------------+-----+----------+
# |[34.0,4500.0]|    1|       0.0|
# +-------------+-----+----------+

# %% [markdown]
# ## Ejemplo 4: Spark GraphX

# %%
# !pip install -q pyspark
# !pyspark --packages graphframes:graphframes:0.8.3-spark3.5-s_2.12
# Out:
# Python 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/content/spark-4.0.1-bin-hadoop3/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2.5.2/cache
# The jars for the packages stored in: /root/.ivy2.5.2/jars
# graphframes#graphframes added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-5510e7fd-415a-4982-a1a4-d52ae35506a1;1.0
# 	confs: [default]
# 	found graphframes#graphframes;0.8.3-spark3.5-s_2.12 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# downloading https://repos.spark-packages.org/graphframes/graphframes/0.8.3-spark3.5-s_2.12/graphframes-0.8.3-spark3.5-s_2.12.jar ...
# 	[SUCCESSFUL ] graphframes#graphframes;0.8.3-spark3.5-s_2.12!graphframes.jar (136ms)
# downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.16/slf4j-api-1.7.16.jar ...
# 	[SUCCESSFUL ] org.slf4j#slf4j-api;1.7.16!slf4j-api.jar (119ms)
# :: resolution report :: resolve 2079ms :: artifacts dl 266ms
# 	:: modules in use:
# 	graphframes#graphframes;0.8.3-spark3.5-s_2.12 from spark-packages in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   2   |   2   |   2   |   0   ||   2   |   2   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-5510e7fd-415a-4982-a1a4-d52ae35506a1
# 	confs: [default]
# 	2 artifacts copied, 0 already retrieved (280kB/27ms)
# 25/11/17 03:44:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/17 03:44:20 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 4.0.1
#       /_/
#
# Using Python version 3.12.12 (main, Oct 10 2025 08:52:57)
# Spark context Web UI available at http://9c87ba892378:4041
# Spark context available as 'sc' (master = local[*], app id = local-1763351060254).
# SparkSession available as 'spark'.
# >>> exit()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("GraphFrames PageRank") \
    .config("spark.jars.packages", "graphframes:graphframes:0.8.3-spark3.5-s_2.12") \
    .getOrCreate()
