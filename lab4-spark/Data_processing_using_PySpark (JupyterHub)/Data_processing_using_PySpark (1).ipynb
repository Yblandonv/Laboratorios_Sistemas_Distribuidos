# %% [markdown]
# # Data Processing using Pyspark

# %%
from pyspark.sql import SparkSession

# Crear SparkSession con configuración para S3
spark = SparkSession.builder \
    .appName("S3Connection") \
    .getOrCreate()

# Configuración de acceso a S3 (AWS Academy)
hadoop_conf = spark._jsc.hadoopConfiguration()
hadoop_conf.set("fs.s3a.access.key", "ASIA5PE4UVOENWGZVQ4V")
hadoop_conf.set("fs.s3a.secret.key", "vW8CY6Ks3V6yWFeDnnVRmyPnEw7eilJllIqbmnGg")
hadoop_conf.set("fs.s3a.session.token", "...")
hadoop_conf.set("fs.s3a.endpoint", "s3.amazonaws.com")
hadoop_conf.set("fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
hadoop_conf.set("spark.hadoop.fs.s3a.path.style.access", "true")

# SparkContext
sc = spark.sparkContext
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>0</td><td>application_1763342042710_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-45-137.ec2.internal:20888/proxy/application_1763342042710_0001/">Link</a></td><td><a target="_blank" href="http://ip-172-31-47-231.ec2.internal:8042/node/containerlogs/container_1763342042710_0001_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df = spark.read.csv('s3a://yasirblandon-datalake/datasets/sample_data.csv', 
                    inferSchema=True, header=True)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#columns of dataframe
df.columns
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ['ratings', 'age', 'experience', 'family', 'mobile']

# %%
#check number of columns
len(df.columns)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 5

# %%
#number of records in dataframe
df.count()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 33

# %%
#shape of dataset
print((df.count(),len(df.columns)))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# (33, 5)

# %%
#printSchema
df.printSchema()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- ratings: integer (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- experience: double (nullable = true)
#  |-- family: integer (nullable = true)
#  |-- mobile: string (nullable = true)

# %%
#fisrt few rows of dataframe
df.show(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+
# |ratings|age|experience|family| mobile|
# +-------+---+----------+------+-------+
# |      3| 32|       9.0|     3|   Vivo|
# |      3| 27|      13.0|     3|  Apple|
# |      4| 22|       2.5|     0|Samsung|
# |      4| 37|      16.5|     4|  Apple|
# |      5| 27|       9.0|     1|     MI|
# +-------+---+----------+------+-------+
# only showing top 5 rows

# %%
#select only 2 columns
df.select('age','mobile').show(5)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+-------+
# |age| mobile|
# +---+-------+
# | 32|   Vivo|
# | 27|  Apple|
# | 22|Samsung|
# | 37|  Apple|
# | 27|     MI|
# +---+-------+
# only showing top 5 rows

# %%
#info about dataframe
df.describe().show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------------+------------------+------------------+------------------+------+
# |summary|           ratings|               age|        experience|            family|mobile|
# +-------+------------------+------------------+------------------+------------------+------+
# |  count|                33|                33|                33|                33|    33|
# |   mean|3.5757575757575757|30.484848484848484|10.303030303030303|1.8181818181818181|  NULL|
# | stddev|1.1188806636071336|  6.18527087180309| 6.770731351213326|1.8448330794164254|  NULL|
# |    min|                 1|                22|               2.5|                 0| Apple|
# |    max|                 5|                42|              23.0|                 5|  Vivo|
# +-------+------------------+------------------+------------------+------------------+------+

# %%
from pyspark.sql.types import StringType,DoubleType,IntegerType
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#add column
df.withColumn("age_after_10_yrs",(df["age"]+10)).show(10,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+----------------+
# |ratings|age|experience|family|mobile |age_after_10_yrs|
# +-------+---+----------+------+-------+----------------+
# |3      |32 |9.0       |3     |Vivo   |42              |
# |3      |27 |13.0      |3     |Apple  |37              |
# |4      |22 |2.5       |0     |Samsung|32              |
# |4      |37 |16.5      |4     |Apple  |47              |
# |5      |27 |9.0       |1     |MI     |37              |
# |4      |27 |9.0       |0     |Oppo   |37              |
# |5      |37 |23.0      |5     |Vivo   |47              |
# |5      |37 |23.0      |5     |Samsung|47              |
# |3      |22 |2.5       |0     |Apple  |32              |
# |3      |27 |6.0       |0     |MI     |37              |
# +-------+---+----------+------+-------+----------------+
# only showing top 10 rows

# %%
#add column
df.withColumn('age_double',df['age'].cast(DoubleType())).show(10,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+----------+
# |ratings|age|experience|family|mobile |age_double|
# +-------+---+----------+------+-------+----------+
# |3      |32 |9.0       |3     |Vivo   |32.0      |
# |3      |27 |13.0      |3     |Apple  |27.0      |
# |4      |22 |2.5       |0     |Samsung|22.0      |
# |4      |37 |16.5      |4     |Apple  |37.0      |
# |5      |27 |9.0       |1     |MI     |27.0      |
# |4      |27 |9.0       |0     |Oppo   |27.0      |
# |5      |37 |23.0      |5     |Vivo   |37.0      |
# |5      |37 |23.0      |5     |Samsung|37.0      |
# |3      |22 |2.5       |0     |Apple  |22.0      |
# |3      |27 |6.0       |0     |MI     |27.0      |
# +-------+---+----------+------+-------+----------+
# only showing top 10 rows

# %%
#add column
df.withColumn("age_after_10_yrs",(df["age"]+10)).show(10,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+----------------+
# |ratings|age|experience|family|mobile |age_after_10_yrs|
# +-------+---+----------+------+-------+----------------+
# |3      |32 |9.0       |3     |Vivo   |42              |
# |3      |27 |13.0      |3     |Apple  |37              |
# |4      |22 |2.5       |0     |Samsung|32              |
# |4      |37 |16.5      |4     |Apple  |47              |
# |5      |27 |9.0       |1     |MI     |37              |
# |4      |27 |9.0       |0     |Oppo   |37              |
# |5      |37 |23.0      |5     |Vivo   |47              |
# |5      |37 |23.0      |5     |Samsung|47              |
# |3      |22 |2.5       |0     |Apple  |32              |
# |3      |27 |6.0       |0     |MI     |37              |
# +-------+---+----------+------+-------+----------------+
# only showing top 10 rows

# %%
#filter the records 
df.filter(df['mobile']=='Vivo').show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+------+
# |ratings|age|experience|family|mobile|
# +-------+---+----------+------+------+
# |      3| 32|       9.0|     3|  Vivo|
# |      5| 37|      23.0|     5|  Vivo|
# |      4| 37|       6.0|     0|  Vivo|
# |      5| 37|      13.0|     1|  Vivo|
# |      4| 37|       6.0|     0|  Vivo|
# +-------+---+----------+------+------+

# %%
#filter the records 
df.filter(df['mobile']=='Vivo').select('age','ratings','mobile').show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+-------+------+
# |age|ratings|mobile|
# +---+-------+------+
# | 32|      3|  Vivo|
# | 37|      5|  Vivo|
# | 37|      4|  Vivo|
# | 37|      5|  Vivo|
# | 37|      4|  Vivo|
# +---+-------+------+

# %%
#filter the multiple conditions
df.filter(df['mobile']=='Vivo').filter(df['experience'] >10).show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+------+
# |ratings|age|experience|family|mobile|
# +-------+---+----------+------+------+
# |      5| 37|      23.0|     5|  Vivo|
# |      5| 37|      13.0|     1|  Vivo|
# +-------+---+----------+------+------+

# %%
#filter the multiple conditions
df.filter((df['mobile']=='Vivo')&(df['experience'] >10)).show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+------+
# |ratings|age|experience|family|mobile|
# +-------+---+----------+------+------+
# |      5| 37|      23.0|     5|  Vivo|
# |      5| 37|      13.0|     1|  Vivo|
# +-------+---+----------+------+------+

# %%
#Distinct Values in a column
df.select('mobile').distinct().show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+
# | mobile|
# +-------+
# |Samsung|
# |     MI|
# |   Oppo|
# |  Apple|
# |   Vivo|
# +-------+

# %%
#distinct value count
df.select('mobile').distinct().count()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 5

# %%
df.groupBy('mobile').count().show(5,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+-----+
# |mobile |count|
# +-------+-----+
# |Samsung|6    |
# |MI     |8    |
# |Oppo   |7    |
# |Apple  |7    |
# |Vivo   |5    |
# +-------+-----+

# %%
# Value counts
df.groupBy('mobile').count().orderBy('count',ascending=False).show(5,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+-----+
# |mobile |count|
# +-------+-----+
# |MI     |8    |
# |Oppo   |7    |
# |Apple  |7    |
# |Samsung|6    |
# |Vivo   |5    |
# +-------+-----+

# %%
# Value counts
df.groupBy('mobile').mean().show(5,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------------+------------------+------------------+------------------+
# |mobile |avg(ratings)      |avg(age)          |avg(experience)   |avg(family)       |
# +-------+------------------+------------------+------------------+------------------+
# |Samsung|4.166666666666667 |28.666666666666668|8.666666666666666 |1.8333333333333333|
# |MI     |3.5               |30.125            |10.1875           |1.375             |
# |Oppo   |2.857142857142857 |28.428571428571427|10.357142857142858|1.4285714285714286|
# |Apple  |3.4285714285714284|30.571428571428573|11.0              |2.7142857142857144|
# |Vivo   |4.2               |36.0              |11.4              |1.8               |
# +-------+------------------+------------------+------------------+------------------+

# %%
df.groupBy('mobile').sum().show(5,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------+--------+---------------+-----------+
# |mobile |sum(ratings)|sum(age)|sum(experience)|sum(family)|
# +-------+------------+--------+---------------+-----------+
# |Samsung|25          |172     |52.0           |11         |
# |MI     |28          |241     |81.5           |11         |
# |Oppo   |20          |199     |72.5           |10         |
# |Apple  |24          |214     |77.0           |19         |
# |Vivo   |21          |180     |57.0           |9          |
# +-------+------------+--------+---------------+-----------+

# %%
# Value counts
df.groupBy('mobile').max().show(5,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------+--------+---------------+-----------+
# |mobile |max(ratings)|max(age)|max(experience)|max(family)|
# +-------+------------+--------+---------------+-----------+
# |Samsung|5           |37      |23.0           |5          |
# |MI     |5           |42      |23.0           |5          |
# |Oppo   |4           |42      |23.0           |2          |
# |Apple  |4           |37      |16.5           |5          |
# |Vivo   |5           |37      |23.0           |5          |
# +-------+------------+--------+---------------+-----------+

# %%
# Value counts
df.groupBy('mobile').min().show(5,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------+--------+---------------+-----------+
# |mobile |min(ratings)|min(age)|min(experience)|min(family)|
# +-------+------------+--------+---------------+-----------+
# |Samsung|2           |22      |2.5            |0          |
# |MI     |1           |27      |2.5            |0          |
# |Oppo   |2           |22      |6.0            |0          |
# |Apple  |3           |22      |2.5            |0          |
# |Vivo   |3           |32      |6.0            |0          |
# +-------+------------+--------+---------------+-----------+

# %%
#Aggregation
df.groupBy('mobile').agg({'experience':'sum'}).show(5,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---------------+
# |mobile |sum(experience)|
# +-------+---------------+
# |Samsung|52.0           |
# |MI     |81.5           |
# |Oppo   |72.5           |
# |Apple  |77.0           |
# |Vivo   |57.0           |
# +-------+---------------+

# %%
# UDF
from pyspark.sql.functions import udf
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#normal function 
def price_range(brand):
    if brand in ['Samsung','Apple']:
        return 'High Price'
    elif brand =='MI':
        return 'Mid Price'
    else:
        return 'Low Price'
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#create udf using python function
brand_udf=udf(price_range,StringType())
#apply udf on dataframe
df.withColumn('price_range',brand_udf(df['mobile'])).show(10,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+-----------+
# |ratings|age|experience|family|mobile |price_range|
# +-------+---+----------+------+-------+-----------+
# |3      |32 |9.0       |3     |Vivo   |Low Price  |
# |3      |27 |13.0      |3     |Apple  |High Price |
# |4      |22 |2.5       |0     |Samsung|High Price |
# |4      |37 |16.5      |4     |Apple  |High Price |
# |5      |27 |9.0       |1     |MI     |Mid Price  |
# |4      |27 |9.0       |0     |Oppo   |Low Price  |
# |5      |37 |23.0      |5     |Vivo   |Low Price  |
# |5      |37 |23.0      |5     |Samsung|High Price |
# |3      |22 |2.5       |0     |Apple  |High Price |
# |3      |27 |6.0       |0     |MI     |Mid Price  |
# +-------+---+----------+------+-------+-----------+
# only showing top 10 rows

# %%
#using lambda function
age_udf = udf(lambda age: "young" if age <= 30 else "senior", StringType())
#apply udf on dataframe
df.withColumn("age_group", age_udf(df.age)).show(10,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+---------+
# |ratings|age|experience|family|mobile |age_group|
# +-------+---+----------+------+-------+---------+
# |3      |32 |9.0       |3     |Vivo   |senior   |
# |3      |27 |13.0      |3     |Apple  |young    |
# |4      |22 |2.5       |0     |Samsung|young    |
# |4      |37 |16.5      |4     |Apple  |senior   |
# |5      |27 |9.0       |1     |MI     |young    |
# |4      |27 |9.0       |0     |Oppo   |young    |
# |5      |37 |23.0      |5     |Vivo   |senior   |
# |5      |37 |23.0      |5     |Samsung|senior   |
# |3      |22 |2.5       |0     |Apple  |young    |
# |3      |27 |6.0       |0     |MI     |young    |
# +-------+---+----------+------+-------+---------+
# only showing top 10 rows

# %%
#pandas udf
from pyspark.sql.functions import pandas_udf, PandasUDFType
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#create python function
def remaining_yrs(age):
    yrs_left=100-age

    return yrs_left
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#create udf using python function
length_udf = pandas_udf(remaining_yrs, IntegerType())
#apply pandas udf on dataframe
df.withColumn("yrs_left", length_udf(df['age'])).show(10,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+--------+
# |ratings|age|experience|family|mobile |yrs_left|
# +-------+---+----------+------+-------+--------+
# |3      |32 |9.0       |3     |Vivo   |68      |
# |3      |27 |13.0      |3     |Apple  |73      |
# |4      |22 |2.5       |0     |Samsung|78      |
# |4      |37 |16.5      |4     |Apple  |63      |
# |5      |27 |9.0       |1     |MI     |73      |
# |4      |27 |9.0       |0     |Oppo   |73      |
# |5      |37 |23.0      |5     |Vivo   |63      |
# |5      |37 |23.0      |5     |Samsung|63      |
# |3      |22 |2.5       |0     |Apple  |78      |
# |3      |27 |6.0       |0     |MI     |73      |
# +-------+---+----------+------+-------+--------+
# only showing top 10 rows

# %%
#udf using two columns 
def prod(rating,exp):
    x=rating*exp
    return x
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#create udf using python function
prod_udf = pandas_udf(prod, DoubleType())
#apply pandas udf on multiple columns of dataframe
df.withColumn("product", prod_udf(df['ratings'],df['experience'])).show(10,False)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+-------+
# |ratings|age|experience|family|mobile |product|
# +-------+---+----------+------+-------+-------+
# |3      |32 |9.0       |3     |Vivo   |27.0   |
# |3      |27 |13.0      |3     |Apple  |39.0   |
# |4      |22 |2.5       |0     |Samsung|10.0   |
# |4      |37 |16.5      |4     |Apple  |66.0   |
# |5      |27 |9.0       |1     |MI     |45.0   |
# |4      |27 |9.0       |0     |Oppo   |36.0   |
# |5      |37 |23.0      |5     |Vivo   |115.0  |
# |5      |37 |23.0      |5     |Samsung|115.0  |
# |3      |22 |2.5       |0     |Apple  |7.5    |
# |3      |27 |6.0       |0     |MI     |18.0   |
# +-------+---+----------+------+-------+-------+
# only showing top 10 rows

# %%
#duplicate values
df.count()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 33

# %%
#drop duplicate values
df=df.dropDuplicates()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#validate new count
df.count()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 26

# %%
#drop column of dataframe
df_new=df.drop('mobile')
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_new.show(10)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+
# |ratings|age|experience|family|
# +-------+---+----------+------+
# |      4| 22|       2.5|     0|
# |      4| 22|       6.0|     1|
# |      3| 27|       6.0|     0|
# |      2| 32|      16.5|     2|
# |      4| 27|       9.0|     0|
# |      3| 37|      16.5|     5|
# |      4| 27|       6.0|     1|
# |      4| 37|       9.0|     2|
# |      3| 22|       2.5|     0|
# |      3| 32|       9.0|     3|
# +-------+---+----------+------+
# only showing top 10 rows

# %%
# saving file to csv
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#target directory 
#pathcsv_out='../out/df_csv'
#pathcsv_out='gdrive/MyDrive/st0263-252/out/df_csv'
# hacia S3
write_uri='s3://yasirblandon-datalake/df_csv1'
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#save the dataframe as single csv 
pathcsv1_out = 's3a://yasirblandon-datalake/df_csv1'
df.coalesce(1).write.format("csv").option("header","true").save(pathcsv1_out)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# parquet
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#target location
#pathparquet_out='../out/df_parquet'
#pathparquet_out='gdrive/MyDrive/st0263-252/out/df_parquet'

# hacia S3
write_uri='s3://yasirblandon-datalake/df_parquet1'
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#save the data into parquet format
pathparquet1_out = 's3://yasirblandon-datalake/df_parquet1'
df.write.format('parquet').save(pathparquet1_out)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
