# %% [markdown]
# # Apache Spark en Google Colab
# Ejercicios de WordCount, DataFrame API y MLlib (clasificación)

# %% [markdown]
# ## Ejemplo 1: WordCount con RDD

# %%
from pyspark.sql import SparkSession

# Esto funciona en EMR; no necesita instalar nada
spark = SparkSession.builder.appName("WordCount S3").getOrCreate()

# El SparkContext ya está listo
sc = spark.sparkContext
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>2</td><td>application_1763342042710_0003</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-45-137.ec2.internal:20888/proxy/application_1763342042710_0003/">Link</a></td><td><a target="_blank" href="http://ip-172-31-47-231.ec2.internal:8042/node/containerlogs/container_1763342042710_0003_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
from pyspark import SparkContext
sc = SparkContext.getOrCreate()

text = sc.textFile("s3://yasirblandon-datalake/datasets/gutenberg-small/*.txt")
# Simular archivo de texto
# text = sc.parallelize(["Hola Spark Hola Big Data", "Spark es rápido y poderoso"])
counts = text.flatMap(lambda x: x.split(" ")) \
             .map(lambda x: (x, 1)) \
             .reduceByKey(lambda a, b: a + b)
counts.collect()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# [('', 27298), ('enters', 7), ('matters', 57), ('anxiety,', 7), ('but', 2485), ('where', 478), ('believe', 421), ('them.', 371), ('themselves', 192), ('especially', 143), ('State', 801), ('perfection', 7), ('armed', 38), ('matter', 257), ('sentiments;', 6), ('given,', 16), ('other', 1267), ('fugitive', 41), ('cases', 141), ('good', 543), ('frame', 35), ('opinion', 269), ('And', 578), ('Constitution.', 78), ('During', 52), ('period', 103), ('They', 422), ('task', 46), ('disruption', 6), ('expressed,', 10), ('forever--it', 3), ('continued', 64), ('expressly', 85), ('plighted', 4), ('PERFECT', 1), ('destruction', 68), ('follows', 26), ('out', 701), ('far', 452), ('masters,', 11), ('regarded', 50), ('hold,', 14), ('strangers', 6), ('current', 41), ('circumstances', 69), ('really', 164), ('speak?', 5), ('step', 42), ('possibility', 13), ('commission', 43), ('not.', 91), ('framed', 119), ('length', 65), ('minorities.', 5), ('produce', 54), ('harmony', 19), ('only,', 31), ('secession?', 4), ('Whoever', 13), ('assumed', 58), ('evils', 27), ('policy', 275), ('fault', 48), ('purposes.', 18), ('extended.', 8), ('substantial', 30), ('dispute.', 7), ('remove', 48), ('impassable', 12), ('advantageous', 17), ('identical', 29), ('again', 203), ('weary', 6), ('amended.', 6), ('opportunity', 60), ('refuse.', 4), ('Congress,', 174), ('executive,', 9), ('came', 201), ('yours', 56), ('wisely', 16), ('countrymen,', 6), ('HURRY', 1), ('sensitive', 5), ('immediate', 50), ('Christianity,', 4), ('yet', 414), ('enemies.', 9), ('strained,', 4), ('patriot', 8), ('broad', 39), ('thoroughly', 15), ('letter', 312), ('A.', 1456), ('ORIGINALS', 1), ('THEY', 1), ('sum', 59), ('singular', 18), ('let', 414), ('particularly', 46), ('Johnston:--', 1), ('_idler_.', 1), ('work', 154), ('wasting', 4), ('habit.', 3), ('charge', 153), ("months'", 7), ('back,', 27), ('unkind', 6), ('contrary,', 65), ('eight', 64), ('1864.', 219), ('Not', 75), ('self', 8), ('constraints', 3), ('truly,', 219), ('USA', 1), ('ago,', 72), ('dead,', 10), ('detract.', 5), ('here.', 89), ('remaining', 55), ("LINCOLN'S", 17), ('GREEN,', 1), ('1910,', 2), ('GREEN', 1), ('INTRODUCTION', 4), ('Political', 6), ('Illinois,', 108), ('Debate', 4), ('12,', 68), ('Message', 10), ('1,', 97), ('Last', 23), ('20,', 46), ('Unlike', 7), ("a'", 1), ('advances', 5), ('family', 43), ('When', 260), ('Irving', 1), ('two,', 24), ('periods', 6), ('shingle', 1), ('growth,', 1), ('once', 212), ('Among,', 1), ('poetry', 1), ('Irish', 5), ('"Oh,', 11), ('Proud?"', 1), ('sort.', 13), ('Among', 31), ('favorite', 15), ('acquainted', 13), ('Petroleum', 1), ('like', 344), ('result', 104), ('preparation.', 3), ('attend', 52), ('oratory.', 1), ('latter', 87), ('interviews', 5), ('sometimes', 61), ('belief', 105), ('personality', 2), ('suggested', 47), ('cordial', 12), ('served', 29), ('leader.', 1), ('works,', 12), ('something', 203), ('command', 131), ('exactly', 75), ('strengthened', 10), ('place,', 76), ('matter,', 43), ('straight.', 2), ('training,', 2), ('constantly', 103), ('recollections', 2), ('trying', 64), ('sayings."', 1), ('letters,', 17), ('soberer', 1), ('sufficiently', 35), ('interesting', 33), ('encounter', 8), ('common', 163), ('approaches', 4), ('General', 912), ('veto,', 3), ("Douglas'", 3), ('conversation.', 3), ('urged', 38), ('hand.', 23), ('dragged', 7), ('bores', 1), ('printing,', 1), ('years,', 71), ('exception', 23), ('Eulogy', 4), ('repeal', 81), ('Compromise.', 26), ('profane', 4), ('connection', 84), ('notes', 28), ('occasion,', 49), ('These', 138), ('performance', 12), ('delivery', 13), ('history,', 41), ('reconstruction', 12), ('cares', 12), ('requests', 5), ('documents', 22), ('concluding', 6), ('emotion.', 2), ('reap', 1), ('biographers,', 2), ('Miss', 9), ('tributes', 1), ('Schurz,', 1), ('references', 1), ('Madison', 9), ('married', 11), ('1831.', 3), ('1834.', 2), ('Reelected', 4), ('Registrar', 1), ('Polk', 9), ('1846-48.', 1), ('1847.', 4), ("Clay's", 21), ('Senator.', 2), ('Fremont', 41), ( ...

# %% [markdown]
# ## Ejemplo 2: Análisis con DataFrame API

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# Simular DataFrame de ventas
data = [("martillo", 12000), ("taladro", 45000), ("martillo", 15000)]
columns = ["producto", "valor"]
df = spark.createDataFrame(data, columns)
df.groupBy("producto").sum("valor").show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------+----------+
# |producto|sum(valor)|
# +--------+----------+
# |martillo|     27000|
# | taladro|     45000|
# +--------+----------+

# %% [markdown]
# ## Ejemplo 3: Clasificación con MLlib

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import LogisticRegression

df = spark.read.csv("s3://yasirblandon-datalake/datasets/clientes.csv", header=True, inferSchema=True)

assembler = VectorAssembler(inputCols=["edad", "ingresos"], outputCol="features")
data = assembler.transform(df).select("features", df["comprador"].alias("label"))
train, test = data.randomSplit([0.8, 0.2], seed=42)
lr = LogisticRegression()
model = lr.fit(train)
model.transform(test).select("features", "label", "prediction").show()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------------+-----+----------+
# |     features|label|prediction|
# +-------------+-----+----------+
# |[34.0,4500.0]|    1|       0.0|
# +-------------+-----+----------+

# %% [markdown]
# ## Ejemplo 4: Spark GraphX

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("GraphFrames PageRank") \
    .config("spark.jars.packages", "graphframes:graphframes:0.8.3-spark3.5-s_2.12") \
    .getOrCreate()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
